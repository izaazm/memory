# %%
from huggingface_hub import login

# Get Hugging Face token from Colab secrets
hf_token = ""  # Replace with your Hugging Face token or use Colab secrets

login(token=hf_token)
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# /tmp/ipykernel_3418/4253848257.py in <cell line: 0>()
#       3
#       4 # Get Hugging Face token from Colab secrets
# ----> 5 hf_token = userdata.get('HF_TOKEN')
#       6
#       7 if hf_token:
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      64     )
#      65   if not resp:
# ---> 66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
#      68     raise SecretNotFoundError(key)
#
# TimeoutException: Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.

# %%
# !git clone https://github.com/izaazm/memory
# %cd memory/cartridges
# !pip install uv
# !uv venv
# !uv pip install -e .
# Out:
# Cloning into 'memory'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 230 (delta 23), reused 229 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (230/230), 9.47 MiB | 14.15 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# /content/memory/cartridges
# ...
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Using Python 3.12.12 environment at: /usr
# Resolved 101 packages in 1.26s
# Prepared 7 packages in 743ms
# Uninstalled 3 packages in 346ms
# Installed 7 packages in 51ms
#  + cartridges==0.0.1 (from file:///content/memory/cartridges)
#  + evaluate==0.4.6
#  - huggingface-hub==1.5.0
#  + huggingface-hub==0.36.2
#  + pydrantic==0.0.3
#  + rouge-score==0.1.2
#  - tokenizers==0.22.2
#  + tokenizers==0.21.4
#  - transformers==5.0.0
#  + transformers==4.55.0

# %%
import os

# path to your the directory where you cloned this repo
# %env CARTRIDGES_DIR=/content/memory/cartridges

# path to a directory where you want to store outputs like models checkpoints and such
# %env CARTRIDGES_OUTPUT_DIR=/content/output

# Create the output directory if it doesn't exist
os.makedirs(os.environ['CARTRIDGES_OUTPUT_DIR'], exist_ok=True)

# the code in this repository is tightly integrated with wandb
# set your wandb project and entity here
# %env CARTRIDGES_WANDB_PROJECT=Cartridges
# %env CARTRIDGES_WANDB_ENTITY=faeyza-rishad-personal
# Out:
# env: CARTRIDGES_DIR=/content/memory/cartridges
# env: CARTRIDGES_OUTPUT_DIR=/content/output
# env: CARTRIDGES_WANDB_PROJECT=Cartridges
# env: CARTRIDGES_WANDB_ENTITY=faeyza-rishad-personal

# %%
# !NUM_AUTHORS=5 NUM_TOKENS=64 MODEL=llama python stress_test/tofu/tofu_train.py
# Out:
# 2026-03-07 04:16:53.780169: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-07 04:16:53.796846: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772857013.816205    5033 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772857013.822615    5033 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
